# %% [markdown]
# # Chapter 8 — Wrapping Up
#
# Chapter ini merangkum proses machine learning end-to-end, dari definisi masalah sampai evaluasi dan kesiapan produksi.

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %% [markdown]
# ## 1. Workflow Umum Machine Learning
#
# 1. Definisikan masalah.
# 2. Pahami data.
# 3. Buat baseline.
# 4. Lakukan preprocessing dan feature engineering.
# 5. Evaluasi model.
# 6. Tuning parameter.
# 7. Dokumentasi dan monitoring.

# %% [markdown]
# ## 2. Mini Project End-to-End

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
cancer = load_breast_cancer(); X, y = cancer.data, cancer.target
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=RANDOM_STATE)
baseline = Pipeline([('scaler', StandardScaler()), ('model', LogisticRegression(max_iter=5000))])
baseline.fit(X_train, y_train)
y_pred = baseline.predict(X_test)
print('Baseline accuracy:', round(baseline.score(X_test,y_test),4))
print(classification_report(y_test, y_pred, target_names=cancer.target_names))
# Out:
# Baseline accuracy: 0.986
#               precision    recall  f1-score   support
#
#    malignant       0.98      0.98      0.98        53
#       benign       0.99      0.99      0.99        90
#
#     accuracy                           0.99       143
#    macro avg       0.99      0.99      0.99       143
# weighted avg       0.99      0.99      0.99       143

# %% [markdown]
# ## 3. Membandingkan Baseline dengan Model Kompleks

# %%
models = {'Logistic Regression': baseline, 'Random Forest': RandomForestClassifier(n_estimators=200, random_state=RANDOM_STATE)}
for name, model in models.items():
    cv = cross_val_score(model, X_train, y_train, cv=5)
    model.fit(X_train, y_train)
    print(name)
    print('  CV mean:', round(cv.mean(),4))
    print('  Test   :', round(model.score(X_test,y_test),4))
# Out:
# Logistic Regression
#   CV mean: 0.9695
#   Test   : 0.986
# Random Forest
#   CV mean: 0.9601
#   Test   : 0.958

# %% [markdown]
# ## 4. Checklist Proyek ML
#
# - Problem jelas?
# - Data valid?
# - Train-test split benar?
# - Preprocessing tidak bocor ke test set?
# - Metrik sesuai tujuan?
# - Baseline sudah dibuat?
# - Model bisa dijelaskan?
# - Eksperimen terdokumentasi?

# %% [markdown]
# ## Kesimpulan
#
# Machine learning adalah proses menyeluruh. Algoritma hanya salah satu bagian; pemahaman masalah, kualitas data, evaluasi, dokumentasi, dan monitoring sama pentingnya.
